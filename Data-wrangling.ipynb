# %%
import pandas as pd
el_universal =  pd.read_csv('Web_Scrapper/eluniversal_2019_04_04_articles.csv')

# %%
#1.- Añadir newspaper _uid al dataframe
el_universal['newspaper_uid'] = 'el_universal'
el_universal.head()
# Out:
#                                                 body  \
# 0  \n\nUn presidente con la mayor votación en la ...
# 1  Debido a que presenta un desempeño presupuesta...
# 2  \nCDMX.- La coordinadora del PES en el Senado,...
# 3  ¿Tu hijo tiene la ciudadanía estadounidense y ...
# 4  \n[email protected]\n\nGuadalajara.— La direct...
#
#                                                title  \
# 0                                         A lo ganso
# 1     El Marqués aumenta su calificación crediticia
# 2  Senadora Sasil de León sostiene que firma en d...
# 3                                                NaN
# 4                   Las Chivas van por súper técnico
#
#                                                  url newspaper_uid
# 0  https://www.eluniversal.com.mx/articulo/carlos...  el_universal
# 1  http://www.eluniversalqueretaro.mx/portada/el-...  el_universal
# 2  https://www.eluniversal.com.mx/nacion/senadora...  el_universal
# 3  http://www.viveusa.mx/educacion/guia-para-tram...  el_universal
# 4  https://www.eluniversal.com.mx/universal-depor...  el_universal

# %%
#2.- Obtener host
from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal.head()
# Out:
#                                                 body  \
# 0  \n\nUn presidente con la mayor votación en la ...
# 1  Debido a que presenta un desempeño presupuesta...
# 2  \nCDMX.- La coordinadora del PES en el Senado,...
# 3  ¿Tu hijo tiene la ciudadanía estadounidense y ...
# 4  \n[email protected]\n\nGuadalajara.— La direct...
#
#                                                title  \
# 0                                         A lo ganso
# 1     El Marqués aumenta su calificación crediticia
# 2  Senadora Sasil de León sostiene que firma en d...
# 3                                                NaN
# 4                   Las Chivas van por súper técnico
#
#                                                  url newspaper_uid  \
# 0  https://www.eluniversal.com.mx/articulo/carlos...  el_universal
# 1  http://www.eluniversalqueretaro.mx/portada/el-...  el_universal
# 2  https://www.eluniversal.com.mx/nacion/senadora...  el_universal
# 3  http://www.viveusa.mx/educacion/guia-para-tram...  el_universal
# 4  https://www.eluniversal.com.mx/universal-depor...  el_universal
#
#                           host
# 0       www.eluniversal.com.mx
# 1  www.eluniversalqueretaro.mx
# 2       www.eluniversal.com.mx
# 3               www.viveusa.mx
# 4       www.eluniversal.com.mx

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx         87
# www.viveusa.mx                  9
# www.elbotiquin.mx               8
# sanluis.eluniversal.com.mx      5
# oaxaca.eluniversal.com.mx       5
# www.eluniversalqueretaro.mx     5
# www.elgrafico.mx                5
# de10.com.mx                     4
# www.unionjalisco.mx             4
# www.unioncdmx.mx                2
# www.unionpuebla.mx              2
# www.unionedomex.mx              2
# www.unionyucatan.mx             2
# www.unionguanajuato.mx          1
# www.clubeluniversal.mx          1
# Name: host, dtype: int64

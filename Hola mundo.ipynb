# %%
print('Hola ingkstr!')
# Out:
# Hola ingkstr!

# %% [markdown]
# # Esto es un título
# ## Esto es un subtitulo
# **Un título tercero**
# *Un titulo final*
# Texto normal

# %%
print('Adios!!!')
# Out:
# Adios!!!
